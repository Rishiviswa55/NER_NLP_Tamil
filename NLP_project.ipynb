# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishiviswa55/NER_NLP_Tamil/blob/main/NLP_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
Reviews = pd.read_csv('Reviews.csv')
Reviews.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
Reviews.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %%
Reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568428 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
Reviews.dropna()
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
Reviews['Text length']=Reviews['Text'].apply(len)
Reviews.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
G = sns.FacetGrid(Reviews,col='Score')
G.map(plt.hist,'Text length')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
sns.boxplot(x='Score',y='Text length',data=Reviews,palette='rainbow')
# Out:
# <ipython-input-22-7fc18f777092>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Score',y='Text length',data=Reviews,palette='rainbow')
# <Axes: xlabel='Score', ylabel='Text length'>

# %%
sns.countplot(x='Score',data=Reviews,palette='rainbow')
# Out:
# <ipython-input-26-e0cc3b6fb869>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Score',data=Reviews,palette='rainbow')
# <Axes: xlabel='Score', ylabel='count'>

# %%
Score = Reviews.groupby('Score').mean(numeric_only=True)
Score
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# Score
# 1      282280.390258              2.735211                4.869825
# 2      280778.019853              1.859014                3.102724
# 3      279645.617495              1.700962                2.466393
# 4      281713.258608              1.390292                1.666084
# 5      285887.043393              1.675228                1.874108
#
#                Time  Text length
# Score
# 1      1.303159e+09   478.082364
# 2      1.301131e+09   490.655010
# 3      1.300126e+09   520.319841
# 4      1.296722e+09   496.603273
# 5      1.294306e+09   402.447373

# %%
Score.corr()
# Out:
#                               Id  HelpfulnessNumerator  \
# Id                      1.000000              0.007005
# HelpfulnessNumerator    0.007005              1.000000
# HelpfulnessDenominator -0.187289              0.975554
# Time                   -0.648444              0.743499
# Text length            -0.980093             -0.015589
#
#                         HelpfulnessDenominator      Time  Text length
# Id                                   -0.187289 -0.648444    -0.980093
# HelpfulnessNumerator                  0.975554  0.743499    -0.015589
# HelpfulnessDenominator                1.000000  0.865762     0.168138
# Time                                  0.865762  1.000000     0.610612
# Text length                           0.168138  0.610612     1.000000

# %%
sns.heatmap(Score.corr(),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
#NLP classification task
Reviews_class = Reviews[(Reviews.Score==1) | (Reviews.Score==5)]

# %%
X = Reviews_class['Text']
y = Reviews_class['Score']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv =CountVectorizer()
X =cv.fit_transform(X)

# %%
# Train_test_split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=101)

# %%
# Training a model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
predictions = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,predictions))
print('/n')
print(classification_report(y_test,predictions))
# Out:
# [[ 12124   3729]
#  [  3924 104840]]
# /n
#               precision    recall  f1-score   support
#
#            1       0.76      0.76      0.76     15853
#            5       0.97      0.96      0.96    108764
#
#     accuracy                           0.94    124617
#    macro avg       0.86      0.86      0.86    124617
# weighted avg       0.94      0.94      0.94    124617

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline

# %%
pipeline =Pipeline([
    ('bow',CountVectorizer()),
    ('tfidff',TfidfTransformer()),
    ('classifier',MultinomialNB()),
])

# %%
X = Reviews_class['Text']
y = Reviews_class['Score']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=101)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidff', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
predictions =pipeline.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[  1877  13976]
#  [    76 108688]]
#               precision    recall  f1-score   support
#
#            1       0.96      0.12      0.21     15853
#            5       0.89      1.00      0.94    108764
#
#     accuracy                           0.89    124617
#    macro avg       0.92      0.56      0.58    124617
# weighted avg       0.90      0.89      0.85    124617
